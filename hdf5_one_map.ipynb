# %%
# %matplotlib notebook
from scripts.open_hdf5 import *
from scripts.map_tool import *

file_directory = get_abs_path("data/map_example.hdf5")

open_one_cmesh = HDF5SingleCmesh()
open_one_cmesh.read_hdf5_map(file_directory, scan_num = 'S3')

single_map = SingleMap(open_one_cmesh)
single_map.plot_xrf()
# Out:
# File is at:  C:\Users\hanr\GitHub\SGMPy\data/map_example.hdf5
# [u'S1', u'S10', u'S11', u'S12', u'S13', u'S14', u'S15', u'S16', u'S17', u'S18', u'S19', u'S2', u'S20', u'S21', u'S22', u'S23', u'S3', u'S4', u'S5', u'S6', u'S7', u'S8', u'S9']
# <img src="data:image/png;base64,...">

# %%
single_map.calculate_pfy(enStart = 75, enStop = 90)
export_info = single_map.plotpfyGridc(file_directory, 1000, 0.5)

export = ExportMap(export_info)
export.save_image()
# Out:
# Plotting contours.
# <img src="data:image/png;base64,...">
# C:\Users\hanr\GitHub\SGMPy\data/map_example_S3_2_pfy_sdd1.tiff
# C:\Users\hanr\GitHub\SGMPy\data/map_example_S3_3_pfy_sdd1.tiff
# C:\Users\hanr\GitHub\SGMPy\data/map_example_S3_4_pfy_sdd1.tiff
# C:\Users\hanr\GitHub\SGMPy\data/map_example_S3_5_pfy_sdd1.tiff

# %%
export_info_2 = single_map.plotpfyGrid(file_directory, 1000, 1000, 0.5)
export_2 = ExportMap(export_info_2)
export_2.save_image()
# Out:
# <img src="data:image/png;base64,...">
# Interpolating MCA1
# Done.
# Interpolating MCA2
# Done.
# Interpolating MCA3
# Done.
# Interpolating MCA4
# Done.
# C:\Users\hanr\GitHub\SGMPy\data/map_example_S3_2_pfy_sdd1.tiff
# C:\Users\hanr\GitHub\SGMPy\data/map_example_S3_3_pfy_sdd1.tiff
# C:\Users\hanr\GitHub\SGMPy\data/map_example_S3_4_pfy_sdd1.tiff
# C:\Users\hanr\GitHub\SGMPy\data/map_example_S3_5_pfy_sdd1.tiff
# C:\Users\hanr\GitHub\SGMPy\data/map_example_S3_6_pfy_sdd1.tiff
