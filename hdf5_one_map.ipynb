# %%
# %matplotlib notebook
import numpy as np
import h5py
from scripts.open_hdf5 import *
from scripts.map_tool import *

# %%
file_directory = get_abs_path("data/resolutiontest.hdf5")
print file_directory
xp_array, yp_array, mca_array, scaler_array, scan_number = read_hdf5_map(file_directory, 'S3')
pfy = get_pfy(mca_array, 75,90)
# Out:
# C:\Users\hanr\GitHub\SGM-Beamline\data/resolutiontest.hdf5
# [u'S1', u'S10', u'S11', u'S12', u'S13', u'S14', u'S15', u'S16', u'S17', u'S18', u'S19', u'S2', u'S20', u'S21', u'S22', u'S23', u'S3', u'S4', u'S5', u'S6', u'S7', u'S8', u'S9']
# Getting PFY ROIs

# %%
z711=plotpfyGrid(xp_array, yp_array, pfy, 1000, 1000, 0.5)
# Out:
# Plotting grids.
# <img src="data:image/png;base64,...">
# Interpolating MCA1
# Done.
# Interpolating MCA2
# Done.
# Interpolating MCA3
# Done.
# Interpolating MCA4
# Done.

# %%
plotpfyGridc(xp_array, yp_array, pfy, 1000, 0.5)
# Out:
# Plotting contours.
# <img src="data:image/png;base64,...">

# %%
plotCntScatter(xp_array, yp_array, scaler_array[0])
# Out:
# <img src="data:image/png;base64,...">

# %%
plotpfyScatter(xp_array, yp_array, pfy)
# Out:
# Making scatter plots.
# <img src="data:image/png;base64,...">
# Done MCA1.
# Done MCA2.
# Done MCA3.
# Done MCA4.

# %%
export_map_all("data/output_map_all2.xas", file_directory, xp_array, yp_array, scaler_array, pfy, "S3")
# Out:
# Stripe: Silicon.
# Fri Apr 29 14:30:36 2016.  Exit Slit: 9.88255
# Export data complete.
