# %%
from praxes.io import spec
import matplotlib.pyplot as plt
from matplotlib.mlab import griddata
import numpy as np
from pylab import imshow, show, get_cmap
from summaryPlot import *
from extract_mca import *

# %%
fileDirectory = 'C:/Users/hanr/Desktop/PyScripts/yongfeng.dat'
print fileDirectory
# Out:
# C:/Users/hanr/Desktop/PyScripts/yongfeng.dat

# %%
generateSummaryPlot(fileDirectory)
# Out:
# Total scan:  91
# index of the for loop is:  0
# Scan No. 1
# Parsing MCAs
# Done!
# index of the for loop is:  1
# Scan No. 2
# Parsing MCAs
# Done!
# index of the for loop is:  2
# Scan No. 3
# Parsing MCAs
# Done!
# index of the for loop is:  3
# Scan No. 4
# Parsing MCAs
# Done!
# index of the for loop is:  4
# Scan No. 5
# Parsing MCAs
# Done!
# index of the for loop is:  5
# Scan No. 6
# Parsing MCAs
# Done!
# index of the for loop is:  6
# Scan No. 7
# Parsing MCAs
# Done!
# index of the for loop is:  7
# Scan No. 8
# Parsing MCAs
# Done!
# index of the for loop is:  8
# Scan No. 9
# Parsing MCAs
# Done!
# index of the for loop is:  9
# Scan No. 10
# Parsing MCAs
# Done!
# index of the for loop is:  10
# Scan No. 11
# Parsing MCAs
# Done!
# index of the for loop is:  11
# Scan No. 12
# Parsing MCAs
# Done!
# index of the for loop is:  12
# Scan No. 13
# Parsing MCAs
# Done!
# index of the for loop is:  13
# Scan No. 14
# Parsing MCAs
# Done!
# index of the for loop is:  14
# Scan No. 15
# Parsing MCAs
# Done!
# index of the for loop is:  15
# Scan No. 16
# Parsing MCAs
# Done!
# index of the for loop is:  16
# Scan No. 17
# Parsing MCAs
# Done!
# index of the for loop is:  17
# Scan No. 18
# Parsing MCAs
# Done!
# index of the for loop is:  18
# Scan No. 19
# Parsing MCAs
# Done!
# index of the for loop is:  19
# Scan No. 20
# Parsing MCAs
# Done!
# index of the for loop is:  20
# Scan No. 21
# Parsing MCAs
# Done!
# index of the for loop is:  21
# Scan No. 22
# Parsing MCAs
# Done!
# index of the for loop is:  22
# Scan No. 23
# Parsing MCAs
# Done!
# index of the for loop is:  23
# Scan No. 24
# Parsing MCAs
# Done!
# index of the for loop is:  24
# Scan No. 25
# Parsing MCAs
# Done!
# index of the for loop is:  25
# Scan No. 26
# Parsing MCAs
# Done!
# index of the for loop is:  26
# Scan No. 27
# Parsing MCAs
# Done!
# index of the for loop is:  27
# Scan No. 28
# Parsing MCAs
# Done!
# index of the for loop is:  28
# Scan No. 29
# Parsing MCAs
# Done!
# index of the for loop is:  29
# Scan No. 30
# Parsing MCAs
# Done!
# index of the for loop is:  30
# Scan No. 31
# Parsing MCAs
# Done!
# index of the for loop is:  31
# Scan No. 32
# Parsing MCAs
# Done!
# index of the for loop is:  32
# Scan No. 33
# Parsing MCAs
# Done!
# index of the for loop is:  33
# Scan No. 34
# Parsing MCAs
# Done!
# index of the for loop is:  34
# Scan No. 35
# Parsing MCAs
# Done!
# index of the for loop is:  35
# Scan No. 36
# Parsing MCAs
# Done!
# index of the for loop is:  36
# Scan No. 37
# Parsing MCAs
# Done!
# index of the for loop is:  37
# Scan No. 38
# Parsing MCAs
# Done!
# index of the for loop is:  38
# Scan No. 39
# Parsing MCAs
# Done!
# index of the for loop is:  39
# Scan No. 40
# Parsing MCAs
# Done!
# index of the for loop is:  40
# Scan No. 41
# Parsing MCAs
# Done!
# index of the for loop is:  41
# Scan No. 42
# Parsing MCAs
# Done!
# index of the for loop is:  42
# Scan No. 43
# Parsing MCAs
# Done!
# index of the for loop is:  43
# Scan No. 44
# Parsing MCAs
# Done!
# index of the for loop is:  44
# Scan No. 45
# Parsing MCAs
# Done!
# index of the for loop is:  45
# Scan No. 46
# Parsing MCAs
# Done!
# index of the for loop is:  46
# Scan No. 47
# Parsing MCAs
# Done!
# index of the for loop is:  47
# Scan No. 48
# Parsing MCAs
# Done!
# index of the for loop is:  48
# Scan No. 49
# Parsing MCAs
# Done!
# index of the for loop is:  49
# Scan No. 50
# Parsing MCAs
# Done!
# index of the for loop is:  50
# Scan No. 51
# Parsing MCAs
# Done!
# index of the for loop is:  51
# Scan No. 52
# Parsing MCAs
# Done!
# index of the for loop is:  52
# Scan No. 53
# Parsing MCAs
# Done!
# index of the for loop is:  53
# Scan No. 54
# Parsing MCAs
# Done!
# index of the for loop is:  54
# Scan No. 55
# Parsing MCAs
# Done!
# index of the for loop is:  55
# Scan No. 56
# Parsing MCAs
# Done!
# index of the for loop is:  56
# Scan No. 57
# Parsing MCAs
# Done!
# index of the for loop is:  57
# Scan No. 58
# Parsing MCAs
# Done!
# index of the for loop is:  58
# Scan No. 59
# Parsing MCAs
# Done!
# index of the for loop is:  59
# Scan No. 60
# Parsing MCAs
# Done!
# index of the for loop is:  60
# Scan No. 61
# Parsing MCAs
# Done!
# index of the for loop is:  61
# Scan No. 62
# Parsing MCAs
# Done!
# index of the for loop is:  62
# Scan No. 63
# Parsing MCAs
# Done!
# index of the for loop is:  63
# Scan No. 64
# Parsing MCAs
# Done!
# index of the for loop is:  64
# Scan No. 65
# Parsing MCAs
# Done!
# index of the for loop is:  65
# Scan No. 66
# Parsing MCAs
# Done!
# index of the for loop is:  66
# Scan No. 67
# Parsing MCAs
# Done!
# index of the for loop is:  67
# Scan No. 68
# Parsing MCAs
# Done!
# index of the for loop is:  68
# Scan No. 69
# Parsing MCAs
# Done!
# index of the for loop is:  69
# Scan No. 70
# Parsing MCAs
# Done!
# index of the for loop is:  70
# Scan No. 71
# Parsing MCAs
# Done!
# index of the for loop is:  71
# Scan No. 72
# Parsing MCAs
# Done!
# index of the for loop is:  72
# Scan No. 73
# Parsing MCAs
# Done!
# index of the for loop is:  73
# Scan No. 74
# Parsing MCAs
# Done!
# index of the for loop is:  74
# Scan No. 75
# Parsing MCAs
# Done!
# index of the for loop is:  75
# Scan No. 76
# Parsing MCAs
# Done!
# index of the for loop is:  76
# Scan No. 77
# Parsing MCAs
# Done!
# index of the for loop is:  77
# Scan No. 78
# Parsing MCAs
# Done!
# index of the for loop is:  78
# Scan No. 79
# Parsing MCAs
# Done!
# index of the for loop is:  79
# Scan No. 80
# Parsing MCAs
# Done!
# index of the for loop is:  80
# Scan No. 81
# Parsing MCAs
# Done!
# index of the for loop is:  81
# Scan No. 82
# Parsing MCAs
# Done!
# index of the for loop is:  82
# Scan No. 83
# Parsing MCAs
# Done!
# index of the for loop is:  83
# Scan No. 84
# Parsing MCAs
# Done!
# index of the for loop is:  84
# Scan No. 85
# Parsing MCAs
# Done!
# index of the for loop is:  85
# Scan No. 86
# Parsing MCAs
# Done!
# index of the for loop is:  86
# Scan No. 87
# Parsing MCAs
# Done!
# index of the for loop is:  87
# Scan No. 88
# Parsing MCAs
# Done!
# index of the for loop is:  88
# Scan No. 89
# Parsing MCAs
# Done!
# index of the for loop is:  89
# Scan No. 90
# Parsing MCAs
# Done!
# index of the for loop is:  90
# Scan No. 91
# Parsing MCAs
# Done!
# Total Scan Number is: 91
# Generating plot for scan No. 1
# Generated plot for scan No. 1 completed
# Generating plot for scan No. 2
# Generated plot for scan No. 2 completed
# Generating plot for scan No. 3
# Generated plot for scan No. 3 completed
# Generating plot for scan No. 4
# Generated plot for scan No. 4 completed
# Generating plot for scan No. 5
# Generated plot for scan No. 5 completed
# Generating plot for scan No. 6
# Generated plot for scan No. 6 completed
# Generating plot for scan No. 7
# Generated plot for scan No. 7 completed
# Generating plot for scan No. 8
# Generated plot for scan No. 8 completed
# Generating plot for scan No. 9
# Generated plot for scan No. 9 completed
# Generating plot for scan No. 10
# Generated plot for scan No. 10 completed
# Generating plot for scan No. 11
# Generated plot for scan No. 11 completed
# Generating plot for scan No. 12
# Generated plot for scan No. 12 completed
# Generating plot for scan No. 13
# Generated plot for scan No. 13 completed
# Generating plot for scan No. 14
# Generated plot for scan No. 14 completed
# Generating plot for scan No. 15
# Generated plot for scan No. 15 completed
# Generating plot for scan No. 16
# Generated plot for scan No. 16 completed
# Generating plot for scan No. 17
# Generated plot for scan No. 17 completed
# Generating plot for scan No. 18
# Generated plot for scan No. 18 completed
# Generating plot for scan No. 19
# Generated plot for scan No. 19 completed
# Generating plot for scan No. 20
# Generated plot for scan No. 20 completed
# Generating plot for scan No. 21
# Generated plot for scan No. 21 completed
# Generating plot for scan No. 22
# Generated plot for scan No. 22 completed
# Generating plot for scan No. 23
# Generated plot for scan No. 23 completed
# Generating plot for scan No. 24
# Generated plot for scan No. 24 completed
# Generating plot for scan No. 25
# Generated plot for scan No. 25 completed
# Generating plot for scan No. 26
# Generated plot for scan No. 26 completed
# Generating plot for scan No. 27
# Generated plot for scan No. 27 completed
# Generating plot for scan No. 28
# Generated plot for scan No. 28 completed
# Generating plot for scan No. 29
# Generated plot for scan No. 29 completed
# Generating plot for scan No. 30
# Generated plot for scan No. 30 completed
# Generating plot for scan No. 31
# Generated plot for scan No. 31 completed
# Generating plot for scan No. 32
# Generated plot for scan No. 32 completed
# Generating plot for scan No. 33
# Generated plot for scan No. 33 completed
# Generating plot for scan No. 34
# Generated plot for scan No. 34 completed
# Generating plot for scan No. 35
# Generated plot for scan No. 35 completed
# Generating plot for scan No. 36
# Generated plot for scan No. 36 completed
# Generating plot for scan No. 37
# Generated plot for scan No. 37 completed
# Generating plot for scan No. 38
# Generated plot for scan No. 38 completed
# Generating plot for scan No. 39
# Generated plot for scan No. 39 completed
# Generating plot for scan No. 40
# Generated plot for scan No. 40 completed
