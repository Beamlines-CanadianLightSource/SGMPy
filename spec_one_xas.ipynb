# %%
# %matplotlib notebook
from scripts.open_spec import *
from scripts.xas_tool import *

file_directory = get_abs_path("data/spectra_example.dat")

opened_one_cscan = OpenSingleCScan()
opened_one_cscan.open_single_xas(file_directory, scan_num = 1)

single_xas = SingleXAS(opened_one_cscan, "single")
single_xas.plot_excitation_emission_matrix("SDD3")
# Out:
# File is at:  C:\Users\hanr\GitHub\SGMPy\data/spectra_example.dat
# Opening scan 1
# Parsing MCAs
# Done!
# <img src="data:image/png;base64,...">

# %%
single_xas.calculate_pfy(enStart = 60, enStop = 80)
single_xas.plot_xas_all()

exported_data = ExportData(single_xas)
exported_data.export_all("data/output_single_xas_all.xas")
# Out:
# Plotting XAS.
# <img src="data:image/png;base64,...">
# Export data complete.
