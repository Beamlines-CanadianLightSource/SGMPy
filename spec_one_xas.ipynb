# %%
# %matplotlib notebook
#import matplotlib.pyplot as plt
#import numpy as np
from scripts.open_spec import *
from scripts.xas_tool import *
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
file_directory = get_abs_path("data/spectra_example.dat")
energy_array, mca_array, scaler_array = open_sgm_xas(file_directory, scan_num=1)
pfy_sdd = get_pfy(mca_array, 60, 80)
# Out:
# Opening scan 1
# in C:\Users\hanr\GitHub\SGM-Beamline\data/spectra_example.dat
# Parsing MCAs
# Done!
# Getting PFY ROIs

# %%
plot_xas(energy_array, "PFY_SDD1", None, pfy_sdd)
# Out:
# Plotting PFY_SDD1 Spectra
# <img src="data:image/png;base64,...">

# %%
matplotlib.rcParams['figure.figsize'] = (8,6)
plot_xas(energy_array, "TEY", scaler_array, None)
# Out:
# Plotting TEY Spectra
# <img src="data:image/png;base64,...">

# %%
matplotlib.rcParams['figure.figsize'] = (12, 16)
plot_xas_all(energy_array, scaler_array, pfy_sdd)
# Out:
# Plotting XAS.
# <img src="data:image/png;base64,...">

# %%
export_data("data/output_tey.xas", file_directory, energy_array, "TEY", scaler_array, "1")
# Out:
# Export data complete!

# %%
export_data("data/output_pfy_sdd1.xas" ,file_directory, energy_array, "PFY_SDD1", None, pfy_sdd, "1")
# Out:
# Export data complete!

# %%
export_all("data/output_all.xas", file_directory, energy_array, scaler_array, pfy_sdd, "1")
# Out:
# Export data complete.
