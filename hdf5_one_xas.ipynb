# %%
# %matplotlib notebook
from scripts.open_hdf5 import *
from scripts.xas_tool import *

file_directory = get_abs_path("data/spectra_example.hdf5")

open_single_cscan = HDF5SingleCScan()
open_single_cscan.read_hdf5_xas(file_directory, scan_number='S9')

single_xas = SingleXAS(open_single_cscan, "single")
single_xas.calculate_pfy(enStart = 60, enStop = 80)

matplotlib.rcParams['figure.figsize'] = (12, 16)
single_xas.plot_xas_all()

exported_data = ExportData(file_directory, single_xas)
exported_data.export_all("data/output_single_xas_all.xas")
# Out:
# File is at:  C:\Users\hanr\GitHub\SGMPy\data/spectra_example.hdf5
# scan  S9 is: cscan
# 29
# Plotting XAS.
# <img src="data:image/png;base64,...">
# Grating: Medium Energy.
# Sun May 15 11:21:33 2016.  Exit Slit: 10.0934
# Export data complete.
