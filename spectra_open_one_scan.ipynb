# %%
# %matplotlib notebook
from praxes.io import spec
import matplotlib.pyplot as plt
import numpy as np
from scripts.basic_plot import *
from scripts.scan_details import *

# %%
file_directory = get_abs_path("data/spectra_example.dat")
opened_scan1 = openSGMXAS(file_directory, scanNum=1)
# Out:
# Opening scan 1
# in C:\Users\hanr\GitHub\SGM-Beamline\data/spectra_example.dat
# Parsing MCAs
# Done!

# %%
pfy_sdd = get_pfy(opened_scan1, 60, 80)
# Out:
# Getting PFY ROIs

# %%
plot_xas(opened_scan1, "PFY_SDD1", pfy_sdd)
# Out:
# Plotting PFY_SDD1 Spectra
# <img src="data:image/png;base64,...">

# %%
print len(opened_scan1[0]['Energy'])
print len(pfy_sdd[0])
# Out:
# 1353
# 1353

# %%
plot_xas(opened_scan1, "TEY")
# Out:
# Plotting TEY Spectra
# <img src="data:image/png;base64,...">
