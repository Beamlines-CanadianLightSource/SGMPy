# %%
# %matplotlib notebook
import numpy as np
import h5py
from scripts.open_spec import *
from scripts.map_tool import *

# %%
file_directory = get_abs_path("data/resolutiontest.dat")
print file_directory
xp_array, yp_array, mca_array, scaler_array, scan_number  = open_sgm_map(file_directory, 23)
pfy = get_pfy(mca_array, 75,90)
# Out:
# C:\Users\hanr\GitHub\SGM-Beamline\data/resolutiontest.dat
# Opening scan 23
# in C:\Users\hanr\GitHub\SGM-Beamline\data/resolutiontest.dat
# Parsing MCAs
# Done!
# Getting PFY ROIs

# %%
image = plotpfyGrid(xp_array, yp_array, pfy, 1000, 1000, 0.5)
# Out:
# Plotting grids.
# <img src="data:image/png;base64,...">
# Interpolating MCA1
# Done.
# Interpolating MCA2
# Done.
# Interpolating MCA3
# Done.
# Interpolating MCA4
# Done.

# %%
plotpfyGridc(xp_array, yp_array, pfy, 1000, 0.5)
# Out:
# Plotting contours.
# <img src="data:image/png;base64,...">

# %%
plotCntScatter(xp_array, yp_array, scaler_array[0])
# Out:
# <img src="data:image/png;base64,...">

# %%
plotpfyScatter(xp_array, yp_array, pfy)
# Out:
# Making scatter plots.
# <img src="data:image/png;base64,...">
# Done MCA1.
# Done MCA2.
# Done MCA3.
# Done MCA4.

# %%
export_map_all("data/output_map_all.xas", file_directory,xp_array, yp_array, scaler_array, pfy, "23")
# Out:
# Export data complete.
