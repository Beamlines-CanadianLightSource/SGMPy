# %%
# %matplotlib notebook
from scripts.open_spec import *
from scripts.map_tool import *

file_directory = get_abs_path("data/map_example.dat")

open_one_cmesh = OpenSingleCMesh()
open_one_cmesh.open_sgm_map(file_directory, scan_num = 23)

single_map = SingleMap(open_one_cmesh)
matplotlib.rcParams['figure.figsize'] = (13, 8)
single_map.plot_xrf()
# Out:
# File is at:  C:\Users\hanr\GitHub\SGMPy\data/map_example.dat
# Opening scan 23
# in C:\Users\hanr\GitHub\SGMPy\data/map_example.dat
# Parsing MCAs
# Done!
# <img src="data:image/png;base64,...">

# %%
single_map.calculate_pfy(enStart = 75, enStop = 90)

matplotlib.rcParams['figure.figsize'] = (10, 8)
single_map.plotpfyGrid(1300, 1000, 0.5)
# Out:
# <img src="data:image/png;base64,...">
# Interpolating MCA1
# Done.
# Interpolating MCA2
# Done.
# Interpolating MCA3
# Done.
# Interpolating MCA4
# Done.

# %%
matplotlib.rcParams['figure.figsize'] = (10, 8)
single_map.plotpfyGridc("map_example", 1000, 0.5)

export = ExportData(file_directory, single_map)
print export.data_set.get_scan_num()
export.export_map_all("data/output_map_all.xas")
# Out:
# Plotting contours.
# <img src="data:image/png;base64,...">
# 23
# Export data complete.
